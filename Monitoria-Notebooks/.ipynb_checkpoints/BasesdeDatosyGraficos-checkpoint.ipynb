# %% [markdown]
# ## Monitoria 3 - Econometría
# ### Pontificia Universidad Javeriana
# #### Bases de Datos y Graficos

# %% [markdown]
# En este documento buscaremos dar una breve explicación de como unir bases de datos, y como realizar algunas estadísticas descriptivas condicionadas. Además daremos varios ejemplos de bases de datos usando la librería matplotlib y seaborn.

# %%
import pandas as pd 
import numpy as np 
import os 

pathout = './data/'
if not os.path.exists(pathout):
    os.mkdir(pathout) 
    pathgraphs = './graphs/'
    if not os.path.exists(pathgraphs): 
        os.mkdir(pathgraphs) 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. Bases de datos:

# %% [markdown]
# ### 1.1 Importar Bases de datos e organizarlas:

# %% [markdown]
# El objetivo final sera unir dos bases de datos, pero antes de poder hacer esto, debemos importar una base de datos y ordenarla para poder usarla.
#
# Las bases de datos que usaremos son datos de estudiantes graduados de educación superior en Colombia en los años 2018 y 2019, Estas bases se llaman grad2018 y grad2019.

# %%
grad2018 = pd.read_excel(pathout + 'grad2018.xlsx')

# %%
grad2018.head(10)
# Notese que la base de datos se importo pero sin nombres y ademas, los primeros 5 datos no nos sirven.
# Out:
#                                           Unnamed: 0 Unnamed: 1  \
# 0    GRADUADOS EN EDUCACIÓN SUPERIOR - COLOMBIA 2018        NaN
# 1    Fecha de corte de la información: Junio de 2019        NaN
# 2  Fuente: Minsiterio de Educación Nacional - Obs...        NaN
# 3  La información suministrada corresponde a lo r...        NaN
# 4  Nota: Para el año 2018, de las 300 IES con per...        NaN
# 5                                                NaN        NaN
# 6                           CÓDIGO DE LA INSTITUCIÓN  IES_PADRE
# 7                                               1101       1101
# 8                                               1101       1101
# 9                                               1101       1101
#
#                                 Unnamed: 2             Unnamed: 3  \
# 0                                      NaN                    NaN
# 1                                      NaN                    NaN
# 2                                      NaN                    NaN
# 3                                      NaN                    NaN
# 4                                      NaN                    NaN
# 5                                      NaN                    NaN
# 6  INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)  PRINCIPAL O SECCIONAL
# 7         UNIVERSIDAD NACIONAL DE COLOMBIA              Principal
# 8         UNIVERSIDAD NACIONAL DE COLOMBIA              Principal
# 9         UNIVERSIDAD NACIONAL DE COLOMBIA              Principal
#
#       Unnamed: 4  Unnamed: 5   Unnamed: 6    Unnamed: 7  \
# 0            NaN         NaN          NaN           NaN
# 1            NaN         NaN          NaN           NaN
# 2            NaN         NaN          NaN           NaN
# 3            NaN         NaN          NaN           NaN
# 4            NaN         NaN          NaN           NaN
# 5            NaN         NaN          NaN           NaN
# 6  ID SECTOR IES  SECTOR IES  ID CARACTER  CARACTER IES
# 7              1     OFICIAL            4   Universidad
# 8              1     OFICIAL            4   Universidad
# 9              1     OFICIAL            4   Universidad
#
#                       Unnamed: 8                           Unnamed: 9  ...  \
# 0                            NaN                                  NaN  ...
# 1                            NaN                                  NaN  ...
# 2                            NaN                                  NaN  ...
# 3                            NaN                                  NaN  ...
# 4                            NaN                                  NaN  ...
# 5                            NaN                                  NaN  ...
# 6  CÓDIGO DEL DEPARTAMENTO (IES)  DEPARTAMENTO DE DOMICILIO DE LA IES  ...
# 7                             11                           BOGOTA D.C  ...
# 8                             11                           BOGOTA D.C  ...
# 9                             11                           BOGOTA D.C  ...
#
#                                 Unnamed: 23  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6      NÚCLEO BÁSICO DEL CONOCIMIENTO (NBC)
# 7  Ingeniería agronómica, pecuaria y afines
# 8  Ingeniería agronómica, pecuaria y afines
# 9  Ingeniería agronómica, pecuaria y afines
#
#                           Unnamed: 24                          Unnamed: 25  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# 5                                 NaN                                  NaN
# 6  CÓDIGO DEL DEPARTAMENTO (PROGRAMA)  DEPARTAMENTO DE OFERTA DEL PROGRAMA
# 7                                  11                           BOGOTA D.C
# 8                                  11                           BOGOTA D.C
# 9                                  11                           BOGOTA D.C
#
#                        Unnamed: 26                       Unnamed: 27  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
# 5                              NaN                               NaN
# 6  CÓDIGO DEL MUNICIPIO (PROGRAMA)  MUNICIPIO DE OFERTA DEL PROGRAMA
# 7                            11001                       BOGOTA D.C.
# 8                            11001                       BOGOTA D.C.
# 9                            11001                       BOGOTA D.C.
#
#   Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
# 5         NaN         NaN         NaN         NaN         NaN
# 6     ID SEXO        SEXO         AÑO    SEMESTRE   GRADUADOS
# 7           1      Hombre        2018           1          16
# 8           1      Hombre        2018           2          35
# 9           2       Mujer        2018           1          17
#
# [10 rows x 33 columns]

# %%
grad2018 = grad2018.drop([0,1, 2, 3, 4,5])  # Podemos eliminar filas de una base de datos de esta manera
grad2018
# Out:
#                      Unnamed: 0 Unnamed: 1  \
# 6      CÓDIGO DE LA INSTITUCIÓN  IES_PADRE
# 7                          1101       1101
# 8                          1101       1101
# 9                          1101       1101
# 10                         1101       1101
# ...                         ...        ...
# 40519                      9915       9915
# 40520                      9915       9915
# 40521                      9915       9915
# 40522                      9922       9922
# 40523                      9922       9922
#
#                                           Unnamed: 2             Unnamed: 3  \
# 6            INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)  PRINCIPAL O SECCIONAL
# 7                   UNIVERSIDAD NACIONAL DE COLOMBIA              Principal
# 8                   UNIVERSIDAD NACIONAL DE COLOMBIA              Principal
# 9                   UNIVERSIDAD NACIONAL DE COLOMBIA              Principal
# 10                  UNIVERSIDAD NACIONAL DE COLOMBIA              Principal
# ...                                              ...                    ...
# 40519            UNIVERSITARIA VIRTUAL INTERNACIONAL              Principal
# 40520            UNIVERSITARIA VIRTUAL INTERNACIONAL              Principal
# 40521            UNIVERSITARIA VIRTUAL INTERNACIONAL              Principal
# 40522  FUNDACION UNIVERSITARIA COMFAMILIAR RISARALDA              Principal
# 40523  FUNDACION UNIVERSITARIA COMFAMILIAR RISARALDA              Principal
#
#           Unnamed: 4  Unnamed: 5   Unnamed: 6  \
# 6      ID SECTOR IES  SECTOR IES  ID CARACTER
# 7                  1     OFICIAL            4
# 8                  1     OFICIAL            4
# 9                  1     OFICIAL            4
# 10                 1     OFICIAL            4
# ...              ...         ...          ...
# 40519              2     PRIVADA            3
# 40520              2     PRIVADA            3
# 40521              2     PRIVADA            3
# 40522              2     PRIVADA            3
# 40523              2     PRIVADA            3
#
#                                           Unnamed: 7  \
# 6                                       CARACTER IES
# 7                                        Universidad
# 8                                        Universidad
# 9                                        Universidad
# 10                                       Universidad
# ...                                              ...
# 40519  Institución Universitaria/Escuela Tecnológica
# 40520  Institución Universitaria/Escuela Tecnológica
# 40521  Institución Universitaria/Escuela Tecnológica
# 40522  Institución Universitaria/Escuela Tecnológica
# 40523  Institución Universitaria/Escuela Tecnológica
#
#                           Unnamed: 8                           Unnamed: 9  \
# 6      CÓDIGO DEL DEPARTAMENTO (IES)  DEPARTAMENTO DE DOMICILIO DE LA IES
# 7                                 11                           BOGOTA D.C
# 8                                 11                           BOGOTA D.C
# 9                                 11                           BOGOTA D.C
# 10                                11                           BOGOTA D.C
# ...                              ...                                  ...
# 40519                             11                           BOGOTA D.C
# 40520                             11                           BOGOTA D.C
# 40521                             11                           BOGOTA D.C
# 40522                             66                            RISARALDA
# 40523                             66                            RISARALDA
#
#        ...                               Unnamed: 23  \
# 6      ...      NÚCLEO BÁSICO DEL CONOCIMIENTO (NBC)
# 7      ...  Ingeniería agronómica, pecuaria y afines
# 8      ...  Ingeniería agronómica, pecuaria y afines
# 9      ...  Ingeniería agronómica, pecuaria y afines
# 10     ...  Ingeniería agronómica, pecuaria y afines
# ...    ...                                       ...
# 40519  ...                        Contaduría pública
# 40520  ...                        Contaduría pública
# 40521  ...                        Contaduría pública
# 40522  ...                        Contaduría pública
# 40523  ...                            Administración
#
#                               Unnamed: 24  \
# 6      CÓDIGO DEL DEPARTAMENTO (PROGRAMA)
# 7                                      11
# 8                                      11
# 9                                      11
# 10                                     11
# ...                                   ...
# 40519                                  11
# 40520                                  11
# 40521                                  11
# 40522                                  66
# 40523                                  66
#
#                                Unnamed: 25                      Unnamed: 26  \
# 6      DEPARTAMENTO DE OFERTA DEL PROGRAMA  CÓDIGO DEL MUNICIPIO (PROGRAMA)
# 7                               BOGOTA D.C                            11001
# 8                               BOGOTA D.C                            11001
# 9                               BOGOTA D.C                            11001
# 10                              BOGOTA D.C                            11001
# ...                                    ...                              ...
# 40519                           BOGOTA D.C                            11001
# 40520                           BOGOTA D.C                            11001
# 40521                           BOGOTA D.C                            11001
# 40522                            RISARALDA                            66001
# 40523                            RISARALDA                            66001
#
#                             Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# 6      MUNICIPIO DE OFERTA DEL PROGRAMA     ID SEXO        SEXO         AÑO
# 7                           BOGOTA D.C.           1      Hombre        2018
# 8                           BOGOTA D.C.           1      Hombre        2018
# 9                           BOGOTA D.C.           2       Mujer        2018
# 10                          BOGOTA D.C.           2       Mujer        2018
# ...                                 ...         ...         ...         ...
# 40519                       BOGOTA D.C.           1      Hombre        2018
# 40520                       BOGOTA D.C.           2       Mujer        2018
# 40521                       BOGOTA D.C.           2       Mujer        2018
# 40522                           PEREIRA           1      Hombre        2018
# 40523                           PEREIRA           2       Mujer        2018
#
#       Unnamed: 31 Unnamed: 32
# 6        SEMESTRE   GRADUADOS
# 7               1          16
# 8               2          35
# 9               1          17
# 10              2          12
# ...           ...         ...
# 40519           1           1
# 40520           1           5
# 40521           2           1
# 40522           2           1
# 40523           2           1
#
# [40518 rows x 33 columns]

# %%
#Notese que la primera fila contiene los nombres de las variables.

nombre_variables = grad2018.iloc[0] #Tomar la primera fila que contiene el nombre de las variables
grad2018.columns = nombre_variables #Cambiarle el nombre a las variables, pero no lo haremos aun
grad2018 = grad2018.drop([6]) #Eliminar la columna que tiene los nombres de las variables

# %%
grad2018.head(5)
# Out:
# 6  CÓDIGO DE LA INSTITUCIÓN IES_PADRE INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)  \
# 7                      1101      1101        UNIVERSIDAD NACIONAL DE COLOMBIA
# 8                      1101      1101        UNIVERSIDAD NACIONAL DE COLOMBIA
# 9                      1101      1101        UNIVERSIDAD NACIONAL DE COLOMBIA
# 10                     1101      1101        UNIVERSIDAD NACIONAL DE COLOMBIA
# 11                     1101      1101        UNIVERSIDAD NACIONAL DE COLOMBIA
#
# 6  PRINCIPAL O SECCIONAL ID SECTOR IES SECTOR IES ID CARACTER CARACTER IES  \
# 7              Principal             1    OFICIAL           4  Universidad
# 8              Principal             1    OFICIAL           4  Universidad
# 9              Principal             1    OFICIAL           4  Universidad
# 10             Principal             1    OFICIAL           4  Universidad
# 11             Principal             1    OFICIAL           4  Universidad
#
# 6  CÓDIGO DEL DEPARTAMENTO (IES) DEPARTAMENTO DE DOMICILIO DE LA IES  ...  \
# 7                             11                          BOGOTA D.C  ...
# 8                             11                          BOGOTA D.C  ...
# 9                             11                          BOGOTA D.C  ...
# 10                            11                          BOGOTA D.C  ...
# 11                            11                          BOGOTA D.C  ...
#
# 6       NÚCLEO BÁSICO DEL CONOCIMIENTO (NBC)  \
# 7   Ingeniería agronómica, pecuaria y afines
# 8   Ingeniería agronómica, pecuaria y afines
# 9   Ingeniería agronómica, pecuaria y afines
# 10  Ingeniería agronómica, pecuaria y afines
# 11                      Medicina veterinaria
#
# 6  CÓDIGO DEL DEPARTAMENTO (PROGRAMA) DEPARTAMENTO DE OFERTA DEL PROGRAMA  \
# 7                                  11                          BOGOTA D.C
# 8                                  11                          BOGOTA D.C
# 9                                  11                          BOGOTA D.C
# 10                                 11                          BOGOTA D.C
# 11                                 11                          BOGOTA D.C
#
# 6  CÓDIGO DEL MUNICIPIO (PROGRAMA) MUNICIPIO DE OFERTA DEL PROGRAMA ID SEXO  \
# 7                            11001                      BOGOTA D.C.       1
# 8                            11001                      BOGOTA D.C.       1
# 9                            11001                      BOGOTA D.C.       2
# 10                           11001                      BOGOTA D.C.       2
# 11                           11001                      BOGOTA D.C.       1
#
# 6     SEXO   AÑO SEMESTRE GRADUADOS
# 7   Hombre  2018        1        16
# 8   Hombre  2018        2        35
# 9    Mujer  2018        1        17
# 10   Mujer  2018        2        12
# 11  Hombre  2018        1         8
#
# [5 rows x 33 columns]

# %% [markdown]
# Ahora debemos hacer lo mismo para los datos de 2019.

# %%
grad2019 = pd.read_excel(pathout + 'grad2019.xlsx')

# %%
grad2019 = grad2019.drop([0,1, 2, 3, 4,5,6])  # Eliminar las filas
nombre_variables2 = grad2019.iloc[0] #Tomar la primera fila que contiene el nombre de las variables
grad2019.columns = nombre_variables2 #Cambiarle el nombre a las variables, pero no lo haremos aun
grad2019 = grad2019.drop([7])  # Eliminar las filas
grad2019.head(10)
# Out:
# 7  CÓDIGO DE LA INSTITUCIÓN IES_PADRE INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)  \
# 8                      1701      1701        PONTIFICIA UNIVERSIDAD JAVERIANA
# 9                      1701      1701        PONTIFICIA UNIVERSIDAD JAVERIANA
# 10                     1701      1701        PONTIFICIA UNIVERSIDAD JAVERIANA
# 11                     1701      1701        PONTIFICIA UNIVERSIDAD JAVERIANA
# 12                     1701      1701        PONTIFICIA UNIVERSIDAD JAVERIANA
# 13                     1701      1701        PONTIFICIA UNIVERSIDAD JAVERIANA
# 14                     1701      1701        PONTIFICIA UNIVERSIDAD JAVERIANA
# 15                     1701      1701        PONTIFICIA UNIVERSIDAD JAVERIANA
# 16                     1701      1701        PONTIFICIA UNIVERSIDAD JAVERIANA
# 17                     1701      1701        PONTIFICIA UNIVERSIDAD JAVERIANA
#
# 7  PRINCIPAL O SECCIONAL ID SECTOR IES SECTOR IES ID CARACTER CARACTER IES  \
# 8              PRINCIPAL             2    PRIVADA           4  UNIVERSIDAD
# 9              PRINCIPAL             2    PRIVADA           4  UNIVERSIDAD
# 10             PRINCIPAL             2    PRIVADA           4  UNIVERSIDAD
# 11             PRINCIPAL             2    PRIVADA           4  UNIVERSIDAD
# 12             PRINCIPAL             2    PRIVADA           4  UNIVERSIDAD
# 13             PRINCIPAL             2    PRIVADA           4  UNIVERSIDAD
# 14             PRINCIPAL             2    PRIVADA           4  UNIVERSIDAD
# 15             PRINCIPAL             2    PRIVADA           4  UNIVERSIDAD
# 16             PRINCIPAL             2    PRIVADA           4  UNIVERSIDAD
# 17             PRINCIPAL             2    PRIVADA           4  UNIVERSIDAD
#
# 7  CÓDIGO DEL DEPARTAMENTO (IES) DEPARTAMENTO DE DOMICILIO DE LA IES  ...  \
# 8                             11                         BOGOTÁ D.C.  ...
# 9                             11                         BOGOTÁ D.C.  ...
# 10                            11                         BOGOTÁ D.C.  ...
# 11                            11                         BOGOTÁ D.C.  ...
# 12                            11                         BOGOTÁ D.C.  ...
# 13                            11                         BOGOTÁ D.C.  ...
# 14                            11                         BOGOTÁ D.C.  ...
# 15                            11                         BOGOTÁ D.C.  ...
# 16                            11                         BOGOTÁ D.C.  ...
# 17                            11                         BOGOTÁ D.C.  ...
#
# 7     SEXO   AÑO SEMESTRE GRADUADOS ID CINE CAMPO AMPLIO  \
# 8    MUJER  2019        1         1                    3
# 9   HOMBRE  2019        1         1                    9
# 10  HOMBRE  2019        1         5                    3
# 11  HOMBRE  2019        1         3                    5
# 12   MUJER  2019        1         2                    2
# 13   MUJER  2019        1         2                    2
# 14  HOMBRE  2019        1         1                    9
# 15   MUJER  2019        1         1                    9
# 16  HOMBRE  2019        1         1                    3
# 17   MUJER  2019        1         1                    2
#
# 7                          DESC CINE CAMPO AMPLIO ID CINE CAMPO ESPECIFICO  \
# 8     CIENCIAS SOCIALES, PERIODISMO E INFORMACIÓN                       31
# 9                               SALUD Y BIENESTAR                       91
# 10    CIENCIAS SOCIALES, PERIODISMO E INFORMACIÓN                       32
# 11  CIENCIAS NATURALES, MATEMÁTICAS Y ESTADÍSTICA                       53
# 12                             ARTE Y HUMANIDADES                       22
# 13                             ARTE Y HUMANIDADES                       22
# 14                              SALUD Y BIENESTAR                       91
# 15                              SALUD Y BIENESTAR                       91
# 16    CIENCIAS SOCIALES, PERIODISMO E INFORMACIÓN                       31
# 17                             ARTE Y HUMANIDADES                       21
#
# 7               DESC CINE CAMPO ESPECIFICO ID CINE CODIGO DETALLADO  \
# 8   CIENCIAS SOCIALES Y DEL COMPORTAMIENTO                      311
# 9                                    SALUD                      912
# 10                PERIODISMO E INFORMACIÓN                      321
# 11                        CIENCIAS FÍSICAS                      531
# 12           HUMANIDADES (EXCEPTO IDIOMAS)                      223
# 13           HUMANIDADES (EXCEPTO IDIOMAS)                      223
# 14                                   SALUD                      912
# 15                                   SALUD                      912
# 16  CIENCIAS SOCIALES Y DEL COMPORTAMIENTO                      314
# 17                                   ARTES                      211
#
# 7                          DESC CINE CODIGO DETALLADO
# 8                                            ECONOMÍA
# 9                                            MEDICINA
# 10              PERIODISMO, COMUNICACIÓN Y REPORTAJES
# 11                                            QUÍMICA
# 12                                  FILOSOFÍA Y ÉTICA
# 13                                  FILOSOFÍA Y ÉTICA
# 14                                           MEDICINA
# 15                                           MEDICINA
# 16     SOCIOLOGÍA, ANTROPOLOGÍA Y ESTUDIOS CULTURALES
# 17  TÉCNICAS AUDIOVISUALES Y PRODUCCIÓN PARA MEDIO...
#
# [10 rows x 39 columns]

# %% [markdown]
# ### 1.2 Unir bases de datos con "append":

# %% [markdown]
# Ahora uniremos ambas bases de datos con el comando append de numpy

# %%
grad = grad2018.append(grad2019, ignore_index=True)

# %%
grad
# Out:
#       CÓDIGO DE LA INSTITUCIÓN IES_PADRE  \
# 0                         1101      1101
# 1                         1101      1101
# 2                         1101      1101
# 3                         1101      1101
# 4                         1101      1101
# ...                        ...       ...
# 82934                     1701      1701
# 82935                     1701      1701
# 82936                     1701      1701
# 82937                     1701      1701
# 82938                     1701      1701
#
#       INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES) PRINCIPAL O SECCIONAL  \
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
# ...                                       ...                   ...
# 82934        PONTIFICIA UNIVERSIDAD JAVERIANA             PRINCIPAL
# 82935        PONTIFICIA UNIVERSIDAD JAVERIANA             PRINCIPAL
# 82936        PONTIFICIA UNIVERSIDAD JAVERIANA             PRINCIPAL
# 82937        PONTIFICIA UNIVERSIDAD JAVERIANA             PRINCIPAL
# 82938        PONTIFICIA UNIVERSIDAD JAVERIANA             PRINCIPAL
#
#       ID SECTOR IES SECTOR IES ID CARACTER CARACTER IES  \
# 0                 1    OFICIAL           4  Universidad
# 1                 1    OFICIAL           4  Universidad
# 2                 1    OFICIAL           4  Universidad
# 3                 1    OFICIAL           4  Universidad
# 4                 1    OFICIAL           4  Universidad
# ...             ...        ...         ...          ...
# 82934             2    PRIVADA           4  UNIVERSIDAD
# 82935             2    PRIVADA           4  UNIVERSIDAD
# 82936             2    PRIVADA           4  UNIVERSIDAD
# 82937             2    PRIVADA           4  UNIVERSIDAD
# 82938             2    PRIVADA           4  UNIVERSIDAD
#
#       CÓDIGO DEL DEPARTAMENTO (IES) DEPARTAMENTO DE DOMICILIO DE LA IES  ...  \
# 0                                11                          BOGOTA D.C  ...
# 1                                11                          BOGOTA D.C  ...
# 2                                11                          BOGOTA D.C  ...
# 3                                11                          BOGOTA D.C  ...
# 4                                11                          BOGOTA D.C  ...
# ...                             ...                                 ...  ...
# 82934                            11                         BOGOTÁ D.C.  ...
# 82935                            11                         BOGOTÁ D.C.  ...
# 82936                            11                         BOGOTÁ D.C.  ...
# 82937                            11                         BOGOTÁ D.C.  ...
# 82938                            11                         BOGOTÁ D.C.  ...
#
#          SEXO   AÑO SEMESTRE GRADUADOS ID CINE CAMPO AMPLIO  \
# 0      Hombre  2018        1        16                  NaN
# 1      Hombre  2018        2        35                  NaN
# 2       Mujer  2018        1        17                  NaN
# 3       Mujer  2018        2        12                  NaN
# 4      Hombre  2018        1         8                  NaN
# ...       ...   ...      ...       ...                  ...
# 82934   MUJER  2019        1         2                    7
# 82935   MUJER  2019        1         3                    9
# 82936  HOMBRE  2019        1         2                    9
# 82937  HOMBRE  2019        1         3                    3
# 82938   MUJER  2019        1         1                    5
#
#                               DESC CINE CAMPO AMPLIO ID CINE CAMPO ESPECIFICO  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
# ...                                              ...                      ...
# 82934           INGENIERÍA, INDUSTRIA Y CONSTRUCCIÓN                       73
# 82935                              SALUD Y BIENESTAR                       91
# 82936                              SALUD Y BIENESTAR                       91
# 82937    CIENCIAS SOCIALES, PERIODISMO E INFORMACIÓN                       32
# 82938  CIENCIAS NATURALES, MATEMÁTICAS Y ESTADÍSTICA                       58
#
#                               DESC CINE CAMPO ESPECIFICO  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 82934                        ARQUITECTURA Y CONSTRUCCIÓN
# 82935                                              SALUD
# 82936                                              SALUD
# 82937                           PERIODISMO E INFORMACIÓN
# 82938  PROGRAMAS Y CERTIFICACIONES INTERDISCIPLINARIO...
#
#       ID CINE CODIGO DETALLADO  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 82934                      732
# 82935                      912
# 82936                      913
# 82937                      322
# 82938                      588
#
#                               DESC CINE CODIGO DETALLADO
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 82934                    CONSTRUCCIÓN E INGENIERÍA CIVIL
# 82935                                           MEDICINA
# 82936                              ENFERMERÍA Y PARTERÍA
# 82937        BIBLIOTECOLOGÍA, INFORMACIÓN Y ARCHIVOLOGÍA
# 82938  PROGRAMAS Y CERTIFICACIONES INTERDISCIPLINARIO...
#
# [82939 rows x 39 columns]

# %% [markdown]
# Si queremos ver que variables tenemos, podemos usar el siguiente comando:

# %%
list(grad)
# Out:
# ['CÓDIGO DE LA INSTITUCIÓN',
#  'IES_PADRE',
#  'INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)',
#  'PRINCIPAL O SECCIONAL',
#  'ID SECTOR IES',
#  'SECTOR IES',
#  'ID CARACTER',
#  'CARACTER IES',
#  'CÓDIGO DEL DEPARTAMENTO (IES)',
#  'DEPARTAMENTO DE DOMICILIO DE LA IES',
#  'CÓDIGO DEL MUNICIPIO',
#  'MUNICIPIO DE DOMICILIO DE LA IES',
#  'CÓDIGO SNIES DEL PROGRAMA',
#  'PROGRAMA ACADÉMICO',
#  'ID NIVEL ACADÉMICO',
#  'NIVEL ACADÉMICO',
#  'ID NIVEL DE FORMACIÓN',
#  'NIVEL DE FORMACIÓN',
#  'ID METODOLOGÍA',
#  'METODOLOGÍA',
#  'ID ÁREA',
#  'ÁREA DE CONOCIMIENTO',
#  'ID NÚCLEO',
#  'NÚCLEO BÁSICO DEL CONOCIMIENTO (NBC)',
#  'CÓDIGO DEL DEPARTAMENTO (PROGRAMA)',
#  'DEPARTAMENTO DE OFERTA DEL PROGRAMA',
#  'CÓDIGO DEL MUNICIPIO (PROGRAMA)',
#  'MUNICIPIO DE OFERTA DEL PROGRAMA',
#  'ID SEXO',
#  'SEXO',
#  'AÑO',
#  'SEMESTRE',
#  'GRADUADOS',
#  'ID CINE CAMPO AMPLIO',
#  'DESC CINE CAMPO AMPLIO',
#  'ID CINE CAMPO ESPECIFICO',
#  'DESC CINE CAMPO ESPECIFICO',
#  'ID CINE CODIGO DETALLADO',
#  'DESC CINE CODIGO DETALLADO']

# %% [markdown]
# #### Nota: Esta vez usamos el comando append para poner la base de datos 2 debajo de la base de datos 1. Podría darse el caso en el que quisiéramos poner una al lado de la otra, por lo que necesitaríamos usar el comando merge de numpy. Un ejemplo de esto seria:

# %% [markdown]
# ### 1.3 Unir Bases de datos con "Merge":

# %% [markdown]
# Supongamos que quisieramos unir estas bases de datos pero poniendo una al lado de la otra. Esto lo hariamos de la siguiente manera:

# %%
#gradmerge = pd.merge(grad2018, grad2019)
#gradmerge
#Dado la forma de los datos, esto no funcionara, pero un ejemplo practico de lo anterior seria el siguiente:

# %%
#Creemos 2 bases de datos cualquiera
df1 = pd.DataFrame({'Empleado': ['Carlos', 'Maria', 'Juan', 'Valentina'],
                    'Carrera': ['Contador', 'Ingeniero', 'Economista', 'Administrador']})
df2 = pd.DataFrame({'Empleado': ['Carlos', 'Maria', 'Juan', 'Valentina'],
                    'Año de contratación': [2015, 2019, 2020, 2020]})
df1
# Out:
#     Empleado        Carrera
# 0     Carlos       Contador
# 1      Maria      Ingeniero
# 2       Juan     Economista
# 3  Valentina  Administrador

# %%
df2
# Out:
#     Empleado  Año de contratación
# 0     Carlos                 2015
# 1      Maria                 2019
# 2       Juan                 2020
# 3  Valentina                 2020

# %% [markdown]
# Si quisiéramos unirlas, lo haríamos de la siguiente manera:

# %%
#Se uniran las bases de datos según variable que sea igual en ambas bases. En este caso, el nombre de los empleados.
df3 = pd.merge(df1, df2)
df3
# Out:
#     Empleado        Carrera  Año de contratación
# 0     Carlos       Contador                 2015
# 1      Maria      Ingeniero                 2019
# 2       Juan     Economista                 2020
# 3  Valentina  Administrador                 2020

# %% [markdown]
# ### 2. Estadísticas Descriptivas:
# Para ver como podemos sacar estadísticas descriptivas con alguna condición volveremos a los datos que guardamos en la base grad que contiene información de estudiantes graduados 2018 y 2019.

# %%
# Estudiantes graduados de la Javeriana en 2018
javeriana = grad2018['CÓDIGO DE LA INSTITUCIÓN'] == 1701

grad_jave_2018 = grad2018.loc[javeriana, 'GRADUADOS'].sum()
print(grad_jave_2018)
# Out:
# 5981

# %%
# Estudiantes graduados de la Javeriana en 2019
javeriana = grad2019['CÓDIGO DE LA INSTITUCIÓN'] == 1701

grad_jave_2019 = grad2019.loc[javeriana, 'GRADUADOS'].sum()
print(grad_jave_2019)
# Out:
# 5714

# %%
#Estudiantes graduados en Bogota
bogota = grad['CÓDIGO DEL DEPARTAMENTO (IES)'] == 11

grad_bogota = grad.loc[bogota, 'GRADUADOS'].sum()
print(grad_bogota)
# Out:
# 288067

# %%
#Estudiantes graduados de economia en 2018 de la javeriana
#Creamos una nueva base de datos para los graduados de la javeriana en 2018
#Al poner la condicióm != estamos eliminando los datos diferentes a 1701, que es el codigo de la Javeriana
javegrad2018 = grad2018.drop(grad2018[grad2018['CÓDIGO DE LA INSTITUCIÓN'] != 1701].index)

#Los estudiantes de pregrado en economia estan guardados en la variable "ID NÚCLEO" con el numero 611
economia = javegrad2018['ID NÚCLEO'] == 611

grad_economia_javeriana = javegrad2018.loc[economia, 'GRADUADOS'].sum()
print(grad_economia_javeriana)
# Out:
# 128
