# %% [markdown]
# ## Monitoria 4 - Econometría
# ### Pontificia Universidad Javeriana
# ####  Mapas de calor
#
# En este documento mostraremos como usar GIS en python. Para empezar graficaremos los casos totales de coronavirus en el mundo para el 20 de mayo del 2021. Luego, graficaremos la velocidad de descarga de internet promedio en un mapa de Colombia por departamento.

# %%
import pandas as pd 
import numpy as np 
import os 

pathout = './data/'
if not os.path.exists(pathout):
    os.mkdir(pathout) 
pathgraphs = './graphs/'
if not os.path.exists(pathgraphs): 
        os.mkdir(pathgraphs)

# %%
from __future__ import division
# %pylab --no-import-all
# %matplotlib inline
import os, sys
import matplotlib as mpl
import seaborn as sns
sns.set()
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
import geopandas as gpd
from geopandas.tools import overlay
from shapely.geometry import Polygon, Point
import georasters as gr
gp = gpd

# %% [markdown]
# ## 1. Mapa del Mundo - Casos Totales Covid 19 (20 de Mayo 2021)
# Traeremos una figura con datos para todos los paises, de la pagina naturaleathdata. Una explicación mas detallada se encuentra en el siguiente repositorio del profesor Omer Ozak: https://github.com/ozak/CompEcon

# %%
covid = pd.read_excel(pathout + 'owid-covid-data.xlsx')

# %%
countries = gpd.read_file('https://www.naturalearthdata.com/http//www.naturalearthdata.com/download/10m/cultural/ne_10m_admin_0_countries.zip')

# %%
countries
# Out:
#           featurecla  scalerank  LABELRANK                    SOVEREIGNT  \
# 0    Admin-0 country          5          2                     Indonesia
# 1    Admin-0 country          5          3                      Malaysia
# 2    Admin-0 country          6          2                         Chile
# 3    Admin-0 country          0          3                       Bolivia
# 4    Admin-0 country          0          2                          Peru
# ..               ...        ...        ...                           ...
# 250  Admin-0 country          0          4                         China
# 251  Admin-0 country          6          5                     Australia
# 252  Admin-0 country          6          8  Bajo Nuevo Bank (Petrel Is.)
# 253  Admin-0 country          6          5               Serranilla Bank
# 254  Admin-0 country          6          6              Scarborough Reef
#
#     SOV_A3  ADM0_DIF  LEVEL               TYPE                         ADMIN  \
# 0      IDN         0      2  Sovereign country                     Indonesia
# 1      MYS         0      2  Sovereign country                      Malaysia
# 2      CHL         0      2  Sovereign country                         Chile
# 3      BOL         0      2  Sovereign country                       Bolivia
# 4      PER         0      2  Sovereign country                          Peru
# ..     ...       ...    ...                ...                           ...
# 250    CH1         1      2            Country                   Macao S.A.R
# 251    AU1         1      2         Dependency   Ashmore and Cartier Islands
# 252    BJN         0      2      Indeterminate  Bajo Nuevo Bank (Petrel Is.)
# 253    SER         0      2      Indeterminate               Serranilla Bank
# 254    SCR         0      2      Indeterminate              Scarborough Reef
#
#     ADM0_A3  ...       NAME_KO                      NAME_NL  \
# 0       IDN  ...         인도네시아                    Indonesië
# 1       MYS  ...         말레이시아                     Maleisië
# 2       CHL  ...            칠레                        Chili
# 3       BOL  ...          볼리비아                      Bolivia
# 4       PER  ...            페루                         Peru
# ..      ...  ...           ...                          ...
# 250     MAC  ...           마카오                        Macau
# 251     ATC  ...  애시모어 카르티에 제도  Ashmore- en Cartiereilanden
# 252     BJN  ...     바호 누에보 뱅크                   Bajo Nuevo
# 253     SER  ...        세라냐 뱅크                   Serranilla
# 254     SCR  ...       스카버러 암초              Scarborough-rif
#
#                       NAME_PL                  NAME_PT  \
# 0                   Indonezja                Indonésia
# 1                     Malezja                  Malásia
# 2                       Chile                    Chile
# 3                     Boliwia                  Bolívia
# 4                        Peru                     Peru
# ..                        ...                      ...
# 250                     Makau                    Macau
# 251  Wyspy Ashmore i Cartiera  Ilhas Ashmore e Cartier
# 252                Bajo Nuevo          Ilha Baixo Novo
# 253           Isla Serranilla          Ilha Serranilla
# 254              Huangyan Dao    Recife de Scarborough
#
#                     NAME_RU                    NAME_SV  \
# 0                 Индонезия                 Indonesien
# 1                  Малайзия                   Malaysia
# 2                      Чили                      Chile
# 3                   Боливия                    Bolivia
# 4                      Перу                       Peru
# ..                      ...                        ...
# 250                   Макао                      Macao
# 251  Острова Ашмор и Картье  Ashmore- och Cartieröarna
# 252              Бахо-Нуэво                 Bajo Nuevo
# 253         Серранилья-Банк            Serranilla Bank
# 254            Скарборо-Шол           Scarboroughrevet
#
#                         NAME_TR                      NAME_VI   NAME_ZH  \
# 0                     Endonezya                    Indonesia     印度尼西亚
# 1                       Malezya                     Malaysia      马来西亚
# 2                          Şili                        Chile        智利
# 3                       Bolivya                      Bolivia      玻利維亞
# 4                          Peru                         Peru        秘鲁
# ..                          ...                          ...       ...
# 250                       Makao                       Ma Cao        澳門
# 251  Ashmore ve Cartier Adaları  Quần đảo Ashmore và Cartier  阿什莫尔和卡捷岛
# 252             Bajo Nuevo Bank              Bajo Nuevo Bank    巴霍努埃沃礁
# 253             Serranilla Bank              Serranilla Bank     塞拉纳浅滩
# 254           Scarborough Shoal          Bãi cạn Scarborough       黄岩岛
#
#                                               geometry
# 0    MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1    MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2    MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3    POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4    MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...
# ..                                                 ...
# 250  MULTIPOLYGON (((113.55860 22.16303, 113.56943 ...
# 251  POLYGON ((123.59702 -12.42832, 123.59775 -12.4...
# 252  POLYGON ((-79.98929 15.79495, -79.98782 15.796...
# 253  POLYGON ((-78.63707 15.86209, -78.64041 15.864...
# 254  POLYGON ((117.75389 15.15437, 117.75569 15.151...
#
# [255 rows x 95 columns]

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(30,20))
countries.plot(ax=ax)
ax.set_title("Mapa del mundo", fontdict={'fontsize':34})
# Out:
# Text(0.5, 1.0, 'Mapa del mundo')

# %%
import geoplot as gplt
import geoplot.crs as gcrs
import mapclassify as mc
import textwrap

# %%
# Functions for plotting
def center_wrap(text, cwidth=32, **kw):
    '''Center Text (to be used in legend)'''
    lines = text
    #lines = textwrap.wrap(text, **kw)
    return "\n".join(line.center(cwidth) for line in lines)

def MyChloropleth(mydf=covid.loc[covid.date=='2020-02-24'], myfile='covid', myvar='total_cases',
                  mylegend='Casos COVID 19 2021 - 05 - 20',
                  k=5,
                  extent=[-180, -90, 180, 90],
                  bbox_to_anchor=(0.2, 0.5),
                  edgecolor='white', facecolor='lightgray',
                  scheme='FisherJenks',
                  save=True,
                  percent=False,
                  **kwargs):
    # Chloropleth
    # Color scheme
    if scheme=='EqualInterval':
        scheme = mc.EqualInterval(mydf[myvar], k=k)
    elif scheme=='Quantiles':
        scheme = mc.Quantiles(mydf[myvar], k=k)
    elif scheme=='BoxPlot':
        scheme = mc.BoxPlot(mydf[myvar], k=k)
    elif scheme=='FisherJenks':
        scheme = mc.FisherJenks(mydf[myvar], k=k)
    elif scheme=='FisherJenksSampled':
        scheme = mc.FisherJenksSampled(mydf[myvar], k=k)
    elif scheme=='HeadTailBreaks':
        scheme = mc.HeadTailBreaks(mydf[myvar], k=k)
    elif scheme=='JenksCaspall':
        scheme = mc.JenksCaspall(mydf[myvar], k=k)
    elif scheme=='JenksCaspallForced':
        scheme = mc.JenksCaspallForced(mydf[myvar], k=k)
    elif scheme=='JenksCaspallSampled':
        scheme = mc.JenksCaspallSampled(mydf[myvar], k=k)
    elif scheme=='KClassifiers':
        scheme = mc.KClassifiers(mydf[myvar], k=k)

        
    upper_bounds = scheme.bins

    
    bounds = []
    for index, upper_bound in enumerate(upper_bounds):
        if index == 0:
            lower_bound = mydf[myvar].min()
        else:
            lower_bound = upper_bounds[index-1]

            
        if percent:
            bound = f'{lower_bound:.0%} - {upper_bound:.0%}'
        else:
            bound = f'{float(lower_bound):,.0f} - {float(upper_bound):,.0f}'
        bounds.append(bound)
    legend_labels = bounds
#Para cambiar el color de la grafica, lo hacemos cambiando el valor en cmap = ''
    ax = gplt.choropleth(
        mydf, hue=myvar, projection=gcrs.PlateCarree(central_longitude=0.0, globe=None),
        edgecolor='white', linewidth=1,
        cmap='RdPu', legend=True,
        scheme=scheme,
        legend_kwargs={'bbox_to_anchor': bbox_to_anchor,
                       'frameon': True,
                       'title':mylegend,
                       },
        legend_labels = legend_labels,
        figsize=(24, 16),
        rasterized=True,
    )
    gplt.polyplot(
        countries, projection=gcrs.PlateCarree(central_longitude=0.0, globe=None),
        edgecolor=edgecolor, facecolor=facecolor,
        ax=ax,
        rasterized=True,
        extent=extent,
    )
    if save:
        plt.savefig(pathgraphs + myfile + '_' + myvar +'.pdf', dpi=300, bbox_inches='tight')
        plt.savefig(pathgraphs + myfile + '_' + myvar +'.png', dpi=300, bbox_inches='tight')
    pass

# %%
covid.head(10)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          1.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          1.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          1.0        0.0
# 8      AFG      Asia  Afghanistan  2020-03-03          2.0        1.0
# 9      AFG      Asia  Afghanistan  2020-03-04          4.0        2.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
# 5               0.143           NaN         NaN                  0.0  ...
# 6               0.143           NaN         NaN                  0.0  ...
# 7               0.000           NaN         NaN                  0.0  ...
# 8               0.143           NaN         NaN                  0.0  ...
# 9               0.429           NaN         NaN                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
# 5        1803.987              NaN                597.029
# 6        1803.987              NaN                597.029
# 7        1803.987              NaN                597.029
# 8        1803.987              NaN                597.029
# 9        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
# 5                 9.59             NaN           NaN                  37.746
# 6                 9.59             NaN           NaN                  37.746
# 7                 9.59             NaN           NaN                  37.746
# 8                 9.59             NaN           NaN                  37.746
# 9                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
# 5                         0.5            64.83                    0.511
# 6                         0.5            64.83                    0.511
# 7                         0.5            64.83                    0.511
# 8                         0.5            64.83                    0.511
# 9                         0.5            64.83                    0.511
#
# [10 rows x 59 columns]

# %%
date = '2021-05-20'
covid1 = covid.loc[covid.date==date].reset_index(drop=True).copy()
covid1 = countries.merge(covid1, left_on='ADM0_A3', right_on='iso_code')
covid1 = covid1.dropna(subset=['total_cases'])
mylegend = center_wrap(["Casos Covid" + str(date)], cwidth=32, width=32)
MyChloropleth(mydf=covid1, myfile='owid-covid-data' + str(date), myvar='total_cases', mylegend=mylegend, scheme='Quantiles', k=10, save=False)

# %% [markdown]
# ## 2. Mapa de Colombia - Velocidad de Internet Promedio por Departamentos (2021)
#
# Usaremos una figura previamente descargada para realizar el mapa de Colombia.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
# %matplotlib inline

# %%
inter = pd.read_excel(pathout + 'internetdpto.xlsx')
inter.sample(5)
# Out:
# /Users/Ingridt/opt/anaconda3/envs/GeoPython38env/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#     COD DEPARTAMENTO  VELOCIDAD_DESCARGA
# 28   81       ARAUCA            4.566667
# 32   97       VAUPES            0.200000
# 4    68    SANTANDER           14.500000
# 6    23      CÓRDOBA           12.510000
# 1    63      QUINDIO           28.383333

# %%
inter.COD = inter.COD.astype('float64')

# %%
depto = gpd.read_file(pathout + 'departamentos.shp')

depto.sample(5)
# Out:
#    ID_ESPACIA  AREA_OFICI          NOMBRE_DPT  \
# 15         54     21658.0  NORTE DE SANTANDER
# 7          23     26506.0             CÓRDOBA
# 22         81     23818.0              ARAUCA
# 3          17      7888.0              CALDAS
# 13         50     85635.0                META
#
#                                              geometry
# 15  POLYGON ((-73.00339 9.28749, -73.00328 9.28744...
# 7   POLYGON ((-75.87806 9.42309, -75.87627 9.42305...
# 22  POLYGON ((-70.67987 7.09254, -70.67905 7.09115...
# 3   POLYGON ((-74.67036 5.77004, -74.66925 5.76905...
# 13  POLYGON ((-71.07957 4.92497, -71.07850 4.92472...

# %%
depto.columns
# Out:
# Index(['ID_ESPACIA', 'AREA_OFICI', 'NOMBRE_DPT', 'geometry'], dtype='object')

# %%
depto.ID_ESPACIA = depto.ID_ESPACIA.astype('float64')

# %%
depto.plot(figsize=(18,9))
plt.show()

# %%
#Uniremos ambas bases de datos a partir del codigo que identifica los departamentos
mapadpt = pd.merge(depto,inter,how='left', left_on ='ID_ESPACIA', right_on = 'COD')

mapadpt.columns
# Out:
# Index(['ID_ESPACIA', 'AREA_OFICI', 'NOMBRE_DPT', 'geometry', 'COD',
#        'DEPARTAMENTO', 'VELOCIDAD_DESCARGA'],
#       dtype='object')

# %%
fig, ax = plt.subplots(1, figsize=(18, 9))
color = 'viridis'
vmin, vmax = 0, 231
sm = plt.cm.ScalarMappable(cmap=color, norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)
cbar.ax.tick_params(labelsize=7)


ax.set_title('Velocidad de descarga promedio por departamento') 

mapadpt.plot('VELOCIDAD_DESCARGA', cmap=color, linewidth=0.8, ax=ax, edgecolor='0.8', figsize=(40,20))
# Out:
# <AxesSubplot:title={'center':'Velocidad de descarga promedio por departamento'}>

# %% [markdown]
# Este es el final del cuarto documento de Introducción a Python para el análisis de datos. Si necesitan cualquier cosa pueden ponerse en contacto conmigo al correo Juan.rinconp@javeriana.edu.co
